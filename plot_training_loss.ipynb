# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
loss = np.load('loss.npz')

# %%
plt.plot(loss["training_loss"], label='training loss')
plt.plot(loss["validate_loss"], label='validation loss')
plt.xlabel('epoch')
plt.title('Training Loss')
plt.legend()
plt.savefig('./figures/train_loss.png')
plt.show()
